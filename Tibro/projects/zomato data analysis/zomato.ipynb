# %% [markdown]
# #Zomato data analysis project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dataframe=pd.read_csv("Zomato data .csv")

def handleRate(value):
    value=str(value).split("/")
    value=value[0]
    return float(value)

dataframe['rate']=dataframe['rate'].apply(handleRate)


sns.countplot(x=dataframe['listed_in(type)'])
plt.xlabel("TYPE OF RESTURANT")
# Out:
# Text(0.5, 0, 'TYPE OF RESTURANT')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dataframe=pd.read_csv("Zomato data .csv")

def handleRate(value):
    value=str(value).split("/")
    value=value[0]
    return float(value)

dataframe['rate']=dataframe['rate'].apply(handleRate)

grouped_data=dataframe.groupby('listed_in(type)')['votes'].sum()
result=pd.DataFrame({'votes':grouped_data})
plt.plot(result,c="green" ,marker="o")
plt.xlabel("Types of restaurant", c="red",size=20)
plt.ylabel("votes", c="red",size=20)
# Out:
# Text(0, 0.5, 'votes')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dataframe=pd.read_csv("Zomato data .csv")

def handleRate(value):
    value=str(value).split("/")
    value=value[0]
    return float(value)

dataframe['rate']=dataframe['rate'].apply(handleRate)

plt.hist(dataframe['rate'],bins=5)
plt.title("ratings distribution")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dataframe=pd.read_csv("Zomato data .csv")

def handleRate(value):
    value=str(value).split("/")
    value=value[0]
    return float(value)

dataframe['rate']=dataframe['rate'].apply(handleRate)

sns.countplot(x=dataframe['approx_cost(for two people)'])
plt.xlabel("price tracking of the orders by couples")
# Out:
# Text(0.5, 0, 'price tracking of the orders by couples')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dataframe=pd.read_csv("Zomato data .csv")

def handleRate(value):
    value=str(value).split("/")
    value=value[0]
    return float(value)

dataframe['rate']=dataframe['rate'].apply(handleRate)

plt.figure(figsize=(8,8))
sns.boxplot(x=dataframe['online_order'],y=dataframe['rate'])
# Out:
# <Axes: xlabel='online_order', ylabel='rate'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dataframe=pd.read_csv("Zomato data .csv")

def handleRate(value):
    value=str(value).split("/")
    value=value[0]
    return float(value)

dataframe['rate']=dataframe['rate'].apply(handleRate)

pivot_table=dataframe.pivot_table(index=dataframe['listed_in(type)'],columns=dataframe['online_order'],aggfunc='size',fill_value=0)
sns.heatmap(pivot_table,annot=True,cmap="YlGnBu",fmt='d')
plt.title("Heatmap")
plt.xlabel("online order")
plt.ylabel('restaurant types')
plt.show()
